# %% [markdown]
# <a href="https://colab.research.google.com/github/saudjabarali/pandas_grind/blob/main/PandasPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🐼 PANDAS START (Structured + Practical)
#
# We’ll do:
#
# Core concepts
# Practice tasks
# Real-world thinking
# 🔹 What is Pandas?
# 🗣️
#
# “Pandas is a Python library used for data manipulation and analysis using DataFrames and Series.”
#
# 🧠 Core Concepts
# Concept	Meaning
# Series	1D labeled array
# DataFrame	2D table (rows + columns)
# Index	Row labels
# Columns	Features
# 🧪 PANDAS PRACTICE SET (PD1–PD20)
# 🟢 LEVEL 1 – Basics
#
# PD1
#
# Create a Series from:
#
# [10, 20, 30, 40]
#
# PD2
#
# Create a DataFrame:
#
# Name   Age
# Saud   20
# Ayaan  21
# Aisha  19
#
# PD3
#
# Read a CSV file
#
#
# PD4
#
# Display:
#
# First 5 rows
# Last 5 rows
# PD5
#
# Get:
#
# Column names
# Data types
#
# 🟡 LEVEL 2 – Selection & Filtering
#
# PD6
#
# Select only Name column
#
#
# PD7
#
# Filter rows where Age > 20
#
#
# PD8
#
# Select multiple columns
#
#
# PD9
#
# Add a new column Salary
#
#
# PD10
#
# Drop a column
#
#
# 🔵 LEVEL 3 – Operations
#
# PD11
#
# Find:
#
# Mean
# Max
# Min
#
# PD12
#
# Sort DataFrame by Age
#
#
# PD13
#
# Handle missing values
#
#
# PD14
#
# Rename columns
#
#
# PD15
#
# Apply function on column
#
#
# 🔴 LEVEL 4 – Advanced
# PD16
#
# Group by Age and count
#
#
# PD17
#
# Merge two DataFrames
#
#
# PD18
#
# Find duplicates
#
#
# PD19
#
# Pivot table
#
#
# PD20
#
# Value counts

# %%
import pandas as pd

# %%
#PD1 Create a Series from: [10, 20, 30, 40]
srs=pd.Series([10,20,30,40])
print(srs)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#PD2 Create a DataFrame: Name Age Saud 20 Ayaan 21 Aisha 19
data= {
    "Name": ["Saud","Ayaan","Aisha"],
    "Age": [20,21,19]
}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0   Saud   20
# 1  Ayaan   21
# 2  Aisha   19

# %%
#PD3-Read a CSV file
df=pd.read_csv("/content/steam_top_games_2026.csv")
df.head()
# Out:
#    app_id                        name  release_date  coming_soon  price_usd  \
# 0  794260  Outward Definitive Edition  May 17, 2022        False       4.79
# 1  253920                    Gorky 17  Sep 27, 2013        False       9.99
# 2  613010             Secret in Story  Jun 19, 2017        False       0.89
# 3  892420                       懒人修仙传  Nov 14, 2018        False       3.99
# 4  914010    Train Station Renovation   Oct 1, 2020        False      18.99
#
#    is_free  discount_pct            developer  \
# 0    False            88     Nine Dots Studio
# 1    False             0  Metropolis Software
# 2    False            10           Naivus Luo
# 3    False             0                托更的修罗
# 4    False             0    Live Motion Games
#
#                                            publisher  \
# 0                          Prime Matter, Deep Silver
# 1                                TopWare Interactive
# 2                                         Naivus Luo
# ...

# %%
#PD4 Display: First 5 rows Last 5 rows
df.tail()
# Out:
#        app_id                  name  release_date  coming_soon  price_usd  \
# 1490  1590910     Forgive Me Father   Apr 7, 2022        False      19.99
# 1491  1693970          PARTY RUSH!!  Mar 23, 2022        False       9.99
# 1492  1225330              NBA 2K21   Sep 4, 2020        False       0.00
# 1493   764030     Realm Revolutions   Jan 5, 2018        False       0.00
# 1494   444200  World of Tanks Blitz   Nov 9, 2016        False       0.00
#
#       is_free  discount_pct                developer                publisher  \
# 1490    False             0              Byte Barrel       Fulqrum Publishing
# 1491    False             0                   SECHAN                HIKE Inc.
# 1492    False             0          Visual Concepts                       2K
# 1493     True             0       Aleksandr Golovkin       Aleksandr Golovkin
# 1494     True             0  Wargaming Group Limited  Wargaming Group Limited
#
# ...

# %%
#PD5 Get:Column names Data types
print(df.columns)
df.dtypes
# Out:
# Index(['app_id', 'name', 'release_date', 'coming_soon', 'price_usd', 'is_free',
#        'discount_pct', 'developer', 'publisher', 'genres', 'categories',
#        'tags', 'platforms_win', 'platforms_mac', 'platforms_linux',
#        'metacritic_score', 'recommendations', 'positive_reviews',
#        'negative_reviews', 'estimated_owners', 'avg_playtime_forever',
#        'avg_playtime_2weeks', 'median_playtime', 'peak_ccu', 'required_age',
#        'dlc_count', 'achievements', 'short_description', 'header_image'],
#       dtype='object')
# app_id                    int64
# name                     object
# release_date             object
# coming_soon                bool
# price_usd               float64
# is_free                    bool
# discount_pct              int64
# developer                object
# publisher                object
# genres                   object
# categories               object
# tags                     object
# platforms_win              bool
# ...

# %%
df=pd.read_csv("/content/pandas_practice.csv")

# %%
df.head()
# Out:
#     Name  Age    Department  Salary       City  Experience
# 0   Saud   20  Data Science   30000    Chennai           1
# 1  Ayaan   21            AI   40000  Bangalore           2
# 2  Aisha   19            HR   25000  Hyderabad           1
# 3  Rahul   25       Finance   50000     Mumbai           3
# 4   Neha   22  Data Science   45000      Delhi           2

# %%
df.tail()
# Out:
#       Name  Age    Department  Salary       City  Experience
# 7    Arjun   26       Finance   52000  Hyderabad           4
# 8   Ritika   21  Data Science   42000     Mumbai           2
# 9   Farhan   28            AI   60000      Delhi           5
# 10   Kiran   27            HR   38000    Chennai           4
# 11   Meena   29       Finance   65000  Bangalore           5

# %%
df.dtypes
# Out:
# Name          object
# Age            int64
# Department    object
# Salary         int64
# City          object
# Experience     int64
# dtype: object

# %%
#PD6 Select only Name column
df["Name"]
# Out:
# 0       Saud
# 1      Ayaan
# 2      Aisha
# 3      Rahul
# 4       Neha
# 5      Imran
# 6       Zara
# 7      Arjun
# 8     Ritika
# 9     Farhan
# 10     Kiran
# 11     Meena
# Name: Name, dtype: object

# %%
#PD7 Filter rows where Age > 20
df[df["Age"]>20]
# Out:
#       Name  Age    Department  Salary       City  Experience
# 1    Ayaan   21            AI   40000  Bangalore           2
# 3    Rahul   25       Finance   50000     Mumbai           3
# 4     Neha   22  Data Science   45000      Delhi           2
# 5    Imran   24            AI   48000    Chennai           3
# 6     Zara   23            HR   35000  Bangalore           2
# 7    Arjun   26       Finance   52000  Hyderabad           4
# 8   Ritika   21  Data Science   42000     Mumbai           2
# 9   Farhan   28            AI   60000      Delhi           5
# 10   Kiran   27            HR   38000    Chennai           4
# 11   Meena   29       Finance   65000  Bangalore           5

# %%
#PD8cSelect multiple columns
df[["Age","Name"]]
# Out:
#     Age    Name
# 0    20    Saud
# 1    21   Ayaan
# 2    19   Aisha
# 3    25   Rahul
# 4    22    Neha
# 5    24   Imran
# 6    23    Zara
# 7    26   Arjun
# 8    21  Ritika
# 9    28  Farhan
# 10   27   Kiran
# 11   29   Meena

# %%
import numpy as np

# %%
#PD9-Add a new column Salary
df["Salary"]=[500000,400000,10000,40000,np.nan,30000,100000,67000,69000,30000,70000,50000]
df.head(12)
# Out:
#       Name  Age    Department    Salary       City  Experience
# 0     Saud   20  Data Science  500000.0    Chennai           1
# 1    Ayaan   21            AI  400000.0  Bangalore           2
# 2    Aisha   19            HR   10000.0  Hyderabad           1
# 3    Rahul   25       Finance   40000.0     Mumbai           3
# 4     Neha   22  Data Science       NaN      Delhi           2
# 5    Imran   24            AI   30000.0    Chennai           3
# 6     Zara   23            HR  100000.0  Bangalore           2
# 7    Arjun   26       Finance   67000.0  Hyderabad           4
# 8   Ritika   21  Data Science   69000.0     Mumbai           2
# 9   Farhan   28            AI   30000.0      Delhi           5
# 10   Kiran   27            HR   70000.0    Chennai           4
# 11   Meena   29       Finance   50000.0  Bangalore           5

# %%
#PD10-Drop a column
df=df.drop("City", axis=1)

# %%
df.head()
# Out:
#     Name  Age    Department    Salary  Experience
# 0   Saud   20  Data Science  500000.0           1
# 1  Ayaan   21            AI  400000.0           2
# 2  Aisha   19            HR   10000.0           1
# 3  Rahul   25       Finance   40000.0           3
# 4   Neha   22  Data Science       NaN           2

# %%
#PD11 Find:Mean Max Min
print(df["Salary"].mean())
print(df["Salary"].max())
print(df["Salary"].min())
# Out:
# 124181.81818181818
# 500000.0
# 10000.0
